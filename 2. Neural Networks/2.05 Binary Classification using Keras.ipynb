# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_url = 'https://raw.githubusercontent.com/PacktWorkshops/The-Deep-Learning-Workshop/master/Chapter02/Datasets/data.csv'
df = pd.read_csv(data_url)
df
# Out:
#     label      x1      x2
# 0       1  2.6487  4.5192
# 1       1  1.5438  2.4443
# 2       1  1.8990  4.2409
# 3       1  2.4711  5.8097
# 4       1  3.3590  6.4423
# 5       1  3.2406  5.8097
# 6       1  3.8128  6.3917
# 7       1  4.4441  6.8725
# 8       1  3.6747  6.7966
# 9       0  7.5417  4.0891
# 10      0  7.2063  2.3937
# 11      0  6.5355  1.3310
# 12      0  5.4503  1.7358
# 13      0  5.8449  2.4443
# 14      0  4.8979  3.1781
# 15      0  5.8055  4.6711
# 16      0  7.3641  5.9868
# 17      0  6.2592  4.6711
# 18      0  8.3703  7.5810
# 19      0  8.5676  4.6457
# 20      0  8.1676  4.6457

# %%
plt.scatter(df[df['label'] == 0]['x1'],
           df[df['label'] == 0]['x2'], marker='*')
plt.scatter(df[df['label'] == 1]['x1'],
           df[df['label'] == 1]['x2'], marker='<')

# %%
x_input = df[['x1', 'x2']].values
y_label = df[['label']].values

# %%
# a neural network model consisting of a single layer with 
# a neuron and a sigmoid activation function
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=1, input_dim=2, activation='sigmoid'))

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_input, y_label, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1306 - accuracy: 1.0000
# Epoch 2/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1305 - accuracy: 1.0000
# Epoch 3/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1304 - accuracy: 1.0000
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 1.0000
# Epoch 5/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1302 - accuracy: 1.0000
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1301 - accuracy: 1.0000
# Epoch 7/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1300 - accuracy: 1.0000
# Epoch 8/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1299 - accuracy: 1.0000
# Epoch 9/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 1.0000
# Epoch 10/1000
# ...

# %%
model.evaluate(x_input, y_label)
# Out:
# 1/1 [==============================] - 0s 201ms/step - loss: 0.0694 - accuracy: 1.0000
# [0.0693625956773758, 1.0]

# %%
# import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
