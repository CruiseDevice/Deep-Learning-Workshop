# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
mymodel = ResNet50()
# Out:
# ...
# 102973440/102967424 [==============================] - 71s 1us/step

# %%
my_image = load_img('im1.jpg', target_size=(224,224))

# %%
my_image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x228C77DC430>

# %%
my_image = img_to_array(my_image)

# %%
my_image
# Out:
# array([[[187., 178., 179.],
#         [189., 180., 181.],
#         [196., 187., 188.],
#         ...,
#         [159.,  95.,  96.],
#         [162., 121., 103.],
#         [154., 113.,  95.]],
#
#        [[193., 184., 185.],
#         [195., 186., 187.],
#         [201., 192., 193.],
#         ...,
#         [169., 108., 107.],
#         [165., 127., 108.],
#         [157., 119., 100.]],
#
#        [[200., 191., 192.],
#         [202., 193., 194.],
#         [207., 198., 199.],
#         ...,
#         [187., 127., 119.],
#         [173., 135., 114.],
#         [166., 128., 107.]],
#
#        ...,
#
#        [[ 78.,  74., 107.],
#         [ 94.,  72.,  58.],
#         [167.,  81.,  24.],
#         ...,
#         [219., 217., 218.],
#         [220., 218., 219.],
#         [220., 218., 219.]],
#
#        [[ 71.,  78., 122.],
#         [ 88.,  75.,  69.],
#         [160.,  80.,  29.],
#         ...,
#         [221., 219., 220.],
#         [219., 217., 218.],
# ...

# %%
my_image = my_image.reshape((1, 224, 224, 3))

# %%
my_image = preprocess_input(my_image)

# %%
myresult = mymodel.predict(my_image)

# %%
mylabel = decode_predictions(myresult)
mylabel
# Out:
# [[('n07873807', 'pizza', 0.8470335),
#   ('n02730930', 'apron', 0.06757549),
#   ('n02834397', 'bib', 0.030353576),
#   ('n07753275', 'pineapple', 0.010753589),
#   ('n03724870', 'mask', 0.004874817)]]

# %%
mylabel = mylabel[0][0]

# %%
mylabel
print(f"This is a: {mylabel[1]} ")
# Out:
# This is a: pizza

# %%
# !pip install gtts

# %%
from gtts import gTTS
import os

# %%
sayit = f"This is a{mylabel[1]}"
myobj = gTTS(text=sayit)

# %%
myobj.save("prediction.mp3")

# %%
os.system("prediction.mp3")
# Out:
# 0

# %%
import torch

# %%
print(torch.version.cuda)
# Out:
# None

# %%
x = torch.Tensor(10).random_(0, 10)
x.to("cuda")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-14-7d8e86e23e9d> in <module>
#       1 x = torch.Tensor(10).random_(0, 10)
# ----> 2 x.to("cuda")
#
# ~\anaconda3\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     194
#     195 class cudaStatus(object):
# --> 196     SUCCESS: int = 0
#     197     ERROR_NOT_READY: int = 34
#     198
#
# ~\anaconda3\lib\site-packages\torch\cuda\__init__.py in _check_driver()
#      92 """
#      93     if torch.version.cuda is None:  # on ROCm we don't want this check
# ---> 94         return
#      95     arch_list = get_arch_list()
#      96     if len(arch_list) == 0:
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
torch.cuda.is_available()
# Out:
# False

# %%
print(torch.__version__)
# Out:
# 1.4.0
